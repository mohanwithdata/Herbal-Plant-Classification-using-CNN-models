# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.1,
    zoom_range=0.1,
    horizontal_flip=True,
    fill_mode='nearest'
)

val_datagen = ImageDataGenerator(rescale=1./255)

test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    r"C:\Users\mohan\Desktop\CA 2\MLOps\Medicinal Leaf Dataset\Medicinal Leaf Dataset\plant_dataset\train",
    target_size=(150, 150),
    batch_size=64,
    class_mode='sparse'
)

val_generator = val_datagen.flow_from_directory(
    r"C:\Users\mohan\Desktop\CA 2\MLOps\Medicinal Leaf Dataset\Medicinal Leaf Dataset\plant_dataset\validation",
    target_size=(150, 150),
    batch_size=64,
    class_mode='sparse'
)

test_generator = test_datagen.flow_from_directory(
    r"C:\Users\mohan\Desktop\CA 2\MLOps\Medicinal Leaf Dataset\Medicinal Leaf Dataset\plant_dataset\test",
    target_size=(150, 150),
    batch_size=64,
    class_mode='sparse'
)
# Out:
# Found 1468 images belonging to 30 classes.
# Found 183 images belonging to 30 classes.
# Found 184 images belonging to 30 classes.

# %%
# import tensorflow as tf
from tensorflow.keras import layers, models, losses
from tensorflow.keras.layers import Resizing
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt

# LeNet model
model = models.Sequential()
model.add(Resizing(224, 224, interpolation="bilinear", input_shape=(150, 150, 3)))
model.add(layers.Conv2D(96, 11, strides=4, padding='same'))
model.add(layers.Lambda(tf.nn.local_response_normalization))
model.add(layers.Activation('relu'))
model.add(layers.MaxPooling2D(3, strides=2))
model.add(layers.Conv2D(256, 5, strides=4, padding='same'))
model.add(layers.Lambda(tf.nn.local_response_normalization))
model.add(layers.Activation('relu'))
model.add(layers.MaxPooling2D(3, strides=2))
model.add(layers.Conv2D(384, 3, strides=4, padding='same'))
model.add(layers.Activation('relu'))
model.add(layers.Conv2D(384, 3, strides=4, padding='same'))
model.add(layers.Activation('relu'))
model.add(layers.Conv2D(256, 3, strides=4, padding='same'))
model.add(layers.Activation('relu'))
model.add(layers.Flatten())
model.add(layers.Dense(4096, activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(4096, activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(30, activation='softmax'))
model.summary()

# Compile the model
model.compile(optimizer=Adam(learning_rate=0.0001), loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Train the model and store the history
history = model.fit(
    train_generator,
    epochs=100,
    validation_data=val_generator,
    verbose=1
)

# Evaluate the model on the test set
test_loss, test_acc = model.evaluate(test_generator, verbose=2)

# Plotting accuracy
plt.figure(figsize=(10, 5))  # Optional: Set the figure size
plt.plot(history.history['accuracy'], label='Training Accuracy')  # Training accuracy
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')  # Validation accuracy
plt.title('Model Accuracy')  # Title for the plot
plt.xlabel('Epochs')  # Label for the x-axis
plt.ylabel('Accuracy')  # Label for the y-axis
plt.ylim([0, 1])  # Limit the y-axis from 0 to 1
plt.legend(loc='lower right')  # Position of the legend
plt.grid(True)  # Optional: Add a grid for better readability
plt.show()  # Display the plot

# Print test accuracy
print(f"Test accuracy: {test_acc}")
# Out:
# C:\Users\mohan\anaconda3\Lib\site-packages\keras\src\layers\preprocessing\tf_data_layer.py:19: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# WARNING:tensorflow:From C:\Users\mohan\anaconda3\Lib\site-packages\keras\src\backend\tensorflow\core.py:204: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ resizing (Resizing)             │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 56, 56, 96)     │        34,944 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lambda (Lambda)                 │ (None, 56, 56, 96)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 56, 56, 96)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 27, 27, 96)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 7, 7, 256)      │       614,656 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lambda_1 (Lambda)               │ (None, 7, 7, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_1 (Activation)       │ (None, 7, 7, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 3, 3, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 1, 1, 384)      │       885,120 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_2 (Activation)       │ (None, 1, 1, 384)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 1, 1, 384)      │     1,327,488 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_3 (Activation)       │ (None, 1, 1, 384)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 1, 1, 256)      │       884,992 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_4 (Activation)       │ (None, 1, 1, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 4096)           │     1,052,672 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 4096)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 4096)           │    16,781,312 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 4096)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 30)             │       122,910 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 21,704,094 (82.79 MB)
#  Trainable params: 21,704,094 (82.79 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# C:\Users\mohan\anaconda3\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 52s 2s/step - accuracy: 0.0422 - loss: 3.3984 - val_accuracy: 0.0656 - val_loss: 3.3697
# Epoch 2/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 45s 1s/step - accuracy: 0.0761 - loss: 3.3543 - val_accuracy: 0.0656 - val_loss: 3.3698
# Epoch 3/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 43s 1s/step - accuracy: 0.0655 - loss: 3.3590 - val_accuracy: 0.0656 - val_loss: 3.3659
# Epoch 4/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 44s 1s/step - accuracy: 0.0658 - loss: 3.3638 - val_accuracy: 0.0656 - val_loss: 3.3652
# Epoch 5/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 45s 2s/step - accuracy: 0.0629 - loss: 3.3610 - val_accuracy: 0.0656 - val_loss: 3.3632
# Epoch 6/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 45s 1s/step - accuracy: 0.0724 - loss: 3.3538 - val_accuracy: 0.0656 - val_loss: 3.3517
# Epoch 7/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 45s 1s/step - accuracy: 0.0641 - loss: 3.3543 - val_accuracy: 0.0492 - val_loss: 3.3083
# Epoch 8/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 46s 2s/step - accuracy: 0.0736 - loss: 3.2466 - val_accuracy: 0.0984 - val_loss: 3.0899
# Epoch 9/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 45s 1s/step - accuracy: 0.0858 - loss: 3.0535 - val_accuracy: 0.0984 - val_loss: 2.9419
# Epoch 10/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 44s 1s/step - accuracy: 0.1045 - loss: 2.9528 - val_accuracy: 0.1311 - val_loss: 2.8374
# Epoch 11/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 43s 1s/step - accuracy: 0.1343 - loss: 2.8484 - val_accuracy: 0.1585 - val_loss: 2.7968
# Epoch 12/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 43s 1s/step - accuracy: 0.1190 - loss: 2.7891 - val_accuracy: 0.1530 - val_loss: 2.7463
# Epoch 13/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 43s 1s/step - accuracy: 0.1508 - loss: 2.7540 - val_accuracy: 0.1694 - val_loss: 2.7637
# Epoch 14/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 42s 1s/step - accuracy: 0.1583 - loss: 2.6923 - val_accuracy: 0.1694 - val_loss: 2.6695
# Epoch 15/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 44s 1s/step - accuracy: 0.1189 - loss: 2.6748 - val_accuracy: 0.1694 - val_loss: 2.6230
# Epoch 16/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 44s 1s/step - accuracy: 0.1567 - loss: 2.6311 - val_accuracy: 0.1858 - val_loss: 2.6305
# Epoch 17/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 44s 1s/step - accuracy: 0.1605 - loss: 2.6433 - val_accuracy: 0.1585 - val_loss: 2.7004
# Epoch 18/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 43s 1s/step - accuracy: 0.1298 - loss: 2.6670 - val_accuracy: 0.1967 - val_loss: 2.5374
# Epoch 19/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 42s 1s/step - accuracy: 0.1835 - loss: 2.5852 - val_accuracy: 0.1967 - val_loss: 2.5226
# Epoch 20/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 42s 1s/step - accuracy: 0.1853 - loss: 2.5120 - val_accuracy: 0.2240 - val_loss: 2.4058
# Epoch 21/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 45s 1s/step - accuracy: 0.2079 - loss: 2.4524 - val_accuracy: 0.2514 - val_loss: 2.4156
# Epoch 22/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 44s 1s/step - accuracy: 0.2306 - loss: 2.3482 - val_accuracy: 0.2951 - val_loss: 2.2593
# Epoch 23/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 44s 1s/step - accuracy: 0.2514 - loss: 2.2662 - val_accuracy: 0.3333 - val_loss: 2.1346
# Epoch 24/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 43s 1s/step - accuracy: 0.2471 - loss: 2.2680 - val_accuracy: 0.3552 - val_loss: 2.0752
# Epoch 25/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 43s 1s/step - accuracy: 0.2708 - loss: 2.1953 - val_accuracy: 0.3388 - val_loss: 2.1340
# Epoch 26/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 45s 2s/step - accuracy: 0.2736 - loss: 2.1403 - val_accuracy: 0.3552 - val_loss: 2.0396
# Epoch 27/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 45s 1s/step - accuracy: 0.3024 - loss: 2.0995 - val_accuracy: 0.3552 - val_loss: 1.9140
# Epoch 28/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 43s 1s/step - accuracy: 0.3021 - loss: 2.1030 - val_accuracy: 0.3443 - val_loss: 1.9336
# Epoch 29/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 43s 1s/step - accuracy: 0.3046 - loss: 2.0231 - val_accuracy: 0.3333 - val_loss: 1.9343
# Epoch 30/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 43s 1s/step - accuracy: 0.3136 - loss: 2.0171 - val_accuracy: 0.3880 - val_loss: 1.9149
# Epoch 31/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 42s 1s/step - accuracy: 0.3164 - loss: 2.0214 - val_accuracy: 0.4262 - val_loss: 1.8362
# Epoch 32/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 44s 1s/step - accuracy: 0.3841 - loss: 1.9052 - val_accuracy: 0.4372 - val_loss: 1.7938
# Epoch 33/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 45s 2s/step - accuracy: 0.3725 - loss: 1.8990 - val_accuracy: 0.4372 - val_loss: 1.8056
# Epoch 34/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 45s 1s/step - accuracy: 0.3802 - loss: 1.8834 - val_accuracy: 0.4426 - val_loss: 1.7012
# Epoch 35/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 43s 1s/step - accuracy: 0.3881 - loss: 1.8165 - val_accuracy: 0.4208 - val_loss: 1.7843
# Epoch 36/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 42s 1s/step - accuracy: 0.3787 - loss: 1.8088 - val_accuracy: 0.4317 - val_loss: 1.7340
# Epoch 37/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 46s 2s/step - accuracy: 0.4089 - loss: 1.7980 - val_accuracy: 0.4645 - val_loss: 1.6032
# Epoch 38/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 46s 1s/step - accuracy: 0.4198 - loss: 1.7080 - val_accuracy: 0.4863 - val_loss: 1.6210
# Epoch 39/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 43s 1s/step - accuracy: 0.4107 - loss: 1.7769 - val_accuracy: 0.4645 - val_loss: 1.6210
# Epoch 40/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 43s 1s/step - accuracy: 0.4310 - loss: 1.7168 - val_accuracy: 0.4973 - val_loss: 1.6274
# Epoch 41/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 43s 1s/step - accuracy: 0.4298 - loss: 1.7009 - val_accuracy: 0.4699 - val_loss: 1.5375
# Epoch 42/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 43s 1s/step - accuracy: 0.4335 - loss: 1.6652 - val_accuracy: 0.5301 - val_loss: 1.4806
# Epoch 43/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 45s 1s/step - accuracy: 0.4783 - loss: 1.5566 - val_accuracy: 0.5519 - val_loss: 1.4275
# Epoch 44/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 43s 1s/step - accuracy: 0.4756 - loss: 1.5911 - val_accuracy: 0.5628 - val_loss: 1.5304
# Epoch 45/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 44s 1s/step - accuracy: 0.4774 - loss: 1.5747 - val_accuracy: 0.5519 - val_loss: 1.4139
# Epoch 46/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 43s 1s/step - accuracy: 0.4895 - loss: 1.5033 - val_accuracy: 0.5301 - val_loss: 1.3621
# Epoch 47/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 42s 1s/step - accuracy: 0.5046 - loss: 1.4171 - val_accuracy: 0.5301 - val_loss: 1.4194
# Epoch 48/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 44s 1s/step - accuracy: 0.5194 - loss: 1.4053 - val_accuracy: 0.5519 - val_loss: 1.3450
# Epoch 49/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 45s 1s/step - accuracy: 0.4901 - loss: 1.5163 - val_accuracy: 0.5792 - val_loss: 1.3313
# Epoch 50/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 44s 1s/step - accuracy: 0.5022 - loss: 1.4158 - val_accuracy: 0.5847 - val_loss: 1.2724
# Epoch 51/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 43s 1s/step - accuracy: 0.5389 - loss: 1.3603 - val_accuracy: 0.5956 - val_loss: 1.2974
# Epoch 52/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 42s 1s/step - accuracy: 0.5768 - loss: 1.2764 - val_accuracy: 0.5902 - val_loss: 1.1962
# Epoch 53/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 43s 1s/step - accuracy: 0.5485 - loss: 1.3317 - val_accuracy: 0.5956 - val_loss: 1.2012
# Epoch 54/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 44s 1s/step - accuracy: 0.6047 - loss: 1.2087 - val_accuracy: 0.6066 - val_loss: 1.1345
# Epoch 55/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 44s 1s/step - accuracy: 0.5611 - loss: 1.2982 - val_accuracy: 0.5956 - val_loss: 1.1714
# Epoch 56/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 43s 1s/step - accuracy: 0.5442 - loss: 1.3231 - val_accuracy: 0.5628 - val_loss: 1.2714
# Epoch 57/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 43s 1s/step - accuracy: 0.5390 - loss: 1.3119 - val_accuracy: 0.6393 - val_loss: 1.0816
# Epoch 58/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 43s 1s/step - accuracy: 0.5842 - loss: 1.1866 - val_accuracy: 0.6120 - val_loss: 1.0814
# Epoch 59/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 44s 2s/step - accuracy: 0.6123 - loss: 1.1393 - val_accuracy: 0.6612 - val_loss: 1.0018
# Epoch 60/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 44s 1s/step - accuracy: 0.5773 - loss: 1.1585 - val_accuracy: 0.6230 - val_loss: 1.0873
# Epoch 61/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 43s 1s/step - accuracy: 0.5819 - loss: 1.1962 - val_accuracy: 0.6393 - val_loss: 1.0511
# Epoch 62/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 42s 1s/step - accuracy: 0.6177 - loss: 1.1067 - val_accuracy: 0.5792 - val_loss: 1.1653
# Epoch 63/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 43s 1s/step - accuracy: 0.5733 - loss: 1.2397 - val_accuracy: 0.5956 - val_loss: 1.0309
# Epoch 64/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 42s 1s/step - accuracy: 0.6150 - loss: 1.0785 - val_accuracy: 0.6339 - val_loss: 1.0075
# Epoch 65/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 44s 1s/step - accuracy: 0.6073 - loss: 1.1103 - val_accuracy: 0.6831 - val_loss: 0.9946
# Epoch 66/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 44s 1s/step - accuracy: 0.6135 - loss: 1.0946 - val_accuracy: 0.6612 - val_loss: 0.9804
# Epoch 67/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 44s 1s/step - accuracy: 0.6149 - loss: 1.0715 - val_accuracy: 0.6448 - val_loss: 0.9843
# Epoch 68/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 43s 1s/step - accuracy: 0.6178 - loss: 1.0747 - val_accuracy: 0.6175 - val_loss: 1.0591
# Epoch 69/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 43s 1s/step - accuracy: 0.6296 - loss: 1.0749 - val_accuracy: 0.6721 - val_loss: 1.0108
# Epoch 70/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 43s 1s/step - accuracy: 0.6056 - loss: 1.1176 - val_accuracy: 0.6831 - val_loss: 0.9037
# Epoch 71/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 44s 1s/step - accuracy: 0.6384 - loss: 1.0161 - val_accuracy: 0.6940 - val_loss: 0.8952
# Epoch 72/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 43s 1s/step - accuracy: 0.6304 - loss: 1.0636 - val_accuracy: 0.6776 - val_loss: 0.9781
# Epoch 73/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 43s 1s/step - accuracy: 0.6135 - loss: 1.0795 - val_accuracy: 0.6557 - val_loss: 0.9697
# Epoch 74/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 42s 1s/step - accuracy: 0.6284 - loss: 1.0420 - val_accuracy: 0.6503 - val_loss: 0.9177
# Epoch 75/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 42s 1s/step - accuracy: 0.6552 - loss: 0.9327 - val_accuracy: 0.6995 - val_loss: 0.9020
# Epoch 76/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 44s 1s/step - accuracy: 0.6352 - loss: 1.0078 - val_accuracy: 0.6995 - val_loss: 0.9032
# Epoch 77/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 43s 1s/step - accuracy: 0.6868 - loss: 0.8865 - val_accuracy: 0.6995 - val_loss: 0.8780
# Epoch 78/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 44s 1s/step - accuracy: 0.6581 - loss: 0.9479 - val_accuracy: 0.7322 - val_loss: 0.8106
# Epoch 79/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 44s 1s/step - accuracy: 0.6852 - loss: 0.8730 - val_accuracy: 0.7541 - val_loss: 0.8246
# Epoch 80/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 43s 1s/step - accuracy: 0.6772 - loss: 0.9395 - val_accuracy: 0.6940 - val_loss: 0.8968
# Epoch 81/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 43s 1s/step - accuracy: 0.6652 - loss: 0.9377 - val_accuracy: 0.7377 - val_loss: 0.8040
# Epoch 82/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 44s 1s/step - accuracy: 0.6549 - loss: 0.9113 - val_accuracy: 0.7432 - val_loss: 0.7811
# Epoch 83/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 43s 1s/step - accuracy: 0.6932 - loss: 0.8836 - val_accuracy: 0.7213 - val_loss: 0.8186
# Epoch 84/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 43s 1s/step - accuracy: 0.6794 - loss: 0.8844 - val_accuracy: 0.7432 - val_loss: 0.7566
# Epoch 85/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 42s 1s/step - accuracy: 0.6967 - loss: 0.8769 - val_accuracy: 0.7158 - val_loss: 0.7819
# Epoch 86/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 43s 1s/step - accuracy: 0.7082 - loss: 0.8622 - val_accuracy: 0.7158 - val_loss: 0.8680
# Epoch 87/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 45s 1s/step - accuracy: 0.7048 - loss: 0.8875 - val_accuracy: 0.7104 - val_loss: 0.8124
# Epoch 88/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 43s 1s/step - accuracy: 0.6893 - loss: 0.8889 - val_accuracy: 0.7541 - val_loss: 0.7584
# Epoch 89/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 43s 1s/step - accuracy: 0.7109 - loss: 0.8337 - val_accuracy: 0.7596 - val_loss: 0.6669
# Epoch 90/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 44s 1s/step - accuracy: 0.7221 - loss: 0.7934 - val_accuracy: 0.7650 - val_loss: 0.6092
# Epoch 91/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 42s 1s/step - accuracy: 0.7308 - loss: 0.7628 - val_accuracy: 0.7869 - val_loss: 0.7118
# Epoch 92/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 43s 1s/step - accuracy: 0.7564 - loss: 0.7411 - val_accuracy: 0.7541 - val_loss: 0.6454
# Epoch 93/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 44s 1s/step - accuracy: 0.7115 - loss: 0.8183 - val_accuracy: 0.7814 - val_loss: 0.6545
# Epoch 94/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 43s 1s/step - accuracy: 0.7256 - loss: 0.7625 - val_accuracy: 0.7268 - val_loss: 0.6345
# Epoch 95/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 43s 1s/step - accuracy: 0.7707 - loss: 0.6792 - val_accuracy: 0.7486 - val_loss: 0.6438
# Epoch 96/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 43s 1s/step - accuracy: 0.7249 - loss: 0.7377 - val_accuracy: 0.7650 - val_loss: 0.6492
# Epoch 97/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 43s 1s/step - accuracy: 0.7358 - loss: 0.7549 - val_accuracy: 0.7869 - val_loss: 0.5805
# Epoch 98/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 45s 2s/step - accuracy: 0.7441 - loss: 0.7443 - val_accuracy: 0.7869 - val_loss: 0.6107
# Epoch 99/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 44s 1s/step - accuracy: 0.7586 - loss: 0.7115 - val_accuracy: 0.7650 - val_loss: 0.6757
# Epoch 100/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 43s 1s/step - accuracy: 0.7277 - loss: 0.7422 - val_accuracy: 0.7978 - val_loss: 0.6014
# 3/3 - 4s - 1s/step - accuracy: 0.7989 - loss: 0.6449
# Test accuracy: 0.7989130616188049
