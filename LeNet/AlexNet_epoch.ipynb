# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.1,
    zoom_range=0.1,
    horizontal_flip=True,
    fill_mode='nearest'
)

val_datagen = ImageDataGenerator(rescale=1./255)

test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    r"C:\Users\mohan\Desktop\CA 2\MLOps\Medicinal Leaf Dataset\Medicinal Leaf Dataset\plant_dataset\train",
    target_size=(150, 150),
    batch_size=64,
    class_mode='sparse'
)

val_generator = val_datagen.flow_from_directory(
    r"C:\Users\mohan\Desktop\CA 2\MLOps\Medicinal Leaf Dataset\Medicinal Leaf Dataset\plant_dataset\validation",
    target_size=(150, 150),
    batch_size=64,
    class_mode='sparse'
)

test_generator = test_datagen.flow_from_directory(
    r"C:\Users\mohan\Desktop\CA 2\MLOps\Medicinal Leaf Dataset\Medicinal Leaf Dataset\plant_dataset\test",
    target_size=(150, 150),
    batch_size=64,
    class_mode='sparse'
)
# Out:
# Found 1468 images belonging to 30 classes.
# Found 183 images belonging to 30 classes.
# Found 184 images belonging to 30 classes.

# %%
# import tensorflow as tf
from tensorflow.keras import layers, models, losses
from tensorflow.keras.layers import Resizing
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt

# LeNet model
model = models.Sequential()
model.add(Resizing(224, 224, interpolation="bilinear", input_shape=(150, 150, 3)))
model.add(layers.Conv2D(96, 11, strides=4, padding='same'))
model.add(layers.Lambda(tf.nn.local_response_normalization))
model.add(layers.Activation('relu'))
model.add(layers.MaxPooling2D(3, strides=2))
model.add(layers.Conv2D(256, 5, strides=4, padding='same'))
model.add(layers.Lambda(tf.nn.local_response_normalization))
model.add(layers.Activation('relu'))
model.add(layers.MaxPooling2D(3, strides=2))
model.add(layers.Conv2D(384, 3, strides=4, padding='same'))
model.add(layers.Activation('relu'))
model.add(layers.Conv2D(384, 3, strides=4, padding='same'))
model.add(layers.Activation('relu'))
model.add(layers.Conv2D(256, 3, strides=4, padding='same'))
model.add(layers.Activation('relu'))
model.add(layers.Flatten())
model.add(layers.Dense(4096, activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(4096, activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(30, activation='softmax'))
model.summary()

# Compile the model
model.compile(optimizer=Adam(learning_rate=0.0001), loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Train the model and store the history
history = model.fit(
    train_generator,
    epochs=100,
    validation_data=val_generator,
    verbose=1
)

# Evaluate the model on the test set
test_loss, test_acc = model.evaluate(test_generator, verbose=2)

# Plotting accuracy
plt.figure(figsize=(10, 5))  # Optional: Set the figure size
plt.plot(history.history['accuracy'], label='Training Accuracy')  # Training accuracy
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')  # Validation accuracy
plt.title('Model Accuracy')  # Title for the plot
plt.xlabel('Epochs')  # Label for the x-axis
plt.ylabel('Accuracy')  # Label for the y-axis
plt.ylim([0, 1])  # Limit the y-axis from 0 to 1
plt.legend(loc='lower right')  # Position of the legend
plt.grid(True)  # Optional: Add a grid for better readability
plt.show()  # Display the plot

# Print test accuracy
print(f"Test accuracy: {test_acc}")
# Out:
# C:\Users\mohan\anaconda3\Lib\site-packages\keras\src\layers\preprocessing\tf_data_layer.py:19: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# WARNING:tensorflow:From C:\Users\mohan\anaconda3\Lib\site-packages\keras\src\backend\tensorflow\core.py:204: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ resizing (Resizing)             │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 56, 56, 96)     │        34,944 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lambda (Lambda)                 │ (None, 56, 56, 96)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 56, 56, 96)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 27, 27, 96)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 7, 7, 256)      │       614,656 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lambda_1 (Lambda)               │ (None, 7, 7, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_1 (Activation)       │ (None, 7, 7, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 3, 3, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 1, 1, 384)      │       885,120 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_2 (Activation)       │ (None, 1, 1, 384)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 1, 1, 384)      │     1,327,488 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_3 (Activation)       │ (None, 1, 1, 384)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 1, 1, 256)      │       884,992 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_4 (Activation)       │ (None, 1, 1, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 4096)           │     1,052,672 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 4096)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 4096)           │    16,781,312 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 4096)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 30)             │       122,910 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 21,704,094 (82.79 MB)
#  Trainable params: 21,704,094 (82.79 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# C:\Users\mohan\anaconda3\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 36s 1s/step - accuracy: 0.0666 - loss: 3.3983 - val_accuracy: 0.0656 - val_loss: 3.3676
# Epoch 2/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 32s 1s/step - accuracy: 0.0658 - loss: 3.3679 - val_accuracy: 0.0656 - val_loss: 3.3655
# Epoch 3/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 32s 1s/step - accuracy: 0.0688 - loss: 3.3483 - val_accuracy: 0.0656 - val_loss: 3.3654
# Epoch 4/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 32s 1s/step - accuracy: 0.0571 - loss: 3.3627 - val_accuracy: 0.0656 - val_loss: 3.3626
# Epoch 5/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 32s 1s/step - accuracy: 0.0644 - loss: 3.3609 - val_accuracy: 0.0656 - val_loss: 3.3584
# Epoch 6/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 32s 1s/step - accuracy: 0.0755 - loss: 3.3369 - val_accuracy: 0.0656 - val_loss: 3.3349
# Epoch 7/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 33s 1s/step - accuracy: 0.0577 - loss: 3.3054 - val_accuracy: 0.0601 - val_loss: 3.2347
# Epoch 8/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 33s 1s/step - accuracy: 0.0849 - loss: 3.2073 - val_accuracy: 0.1148 - val_loss: 2.9775
# Epoch 9/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 33s 1s/step - accuracy: 0.1167 - loss: 2.9713 - val_accuracy: 0.1421 - val_loss: 2.7963
# Epoch 10/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 33s 1s/step - accuracy: 0.1287 - loss: 2.8164 - val_accuracy: 0.1093 - val_loss: 2.8534
# Epoch 11/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 32s 1s/step - accuracy: 0.1258 - loss: 2.8501 - val_accuracy: 0.1311 - val_loss: 2.8399
# Epoch 12/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 32s 1s/step - accuracy: 0.1320 - loss: 2.6943 - val_accuracy: 0.1639 - val_loss: 2.6464
# Epoch 13/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 32s 1s/step - accuracy: 0.1570 - loss: 2.6223 - val_accuracy: 0.1530 - val_loss: 2.6051
# Epoch 14/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 32s 1s/step - accuracy: 0.1615 - loss: 2.6033 - val_accuracy: 0.1967 - val_loss: 2.5907
# Epoch 15/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 33s 1s/step - accuracy: 0.1819 - loss: 2.5590 - val_accuracy: 0.2131 - val_loss: 2.4866
# Epoch 16/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 33s 1s/step - accuracy: 0.2019 - loss: 2.4210 - val_accuracy: 0.2350 - val_loss: 2.4428
# Epoch 17/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 32s 1s/step - accuracy: 0.2272 - loss: 2.3847 - val_accuracy: 0.2896 - val_loss: 2.3347
# Epoch 18/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 32s 1s/step - accuracy: 0.2321 - loss: 2.3126 - val_accuracy: 0.2951 - val_loss: 2.1833
# Epoch 19/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 33s 1s/step - accuracy: 0.2531 - loss: 2.2879 - val_accuracy: 0.2842 - val_loss: 2.0524
# Epoch 20/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 33s 1s/step - accuracy: 0.2520 - loss: 2.2033 - val_accuracy: 0.3005 - val_loss: 2.1460
# Epoch 21/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 33s 1s/step - accuracy: 0.3115 - loss: 2.1241 - val_accuracy: 0.3388 - val_loss: 2.0558
# Epoch 22/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 33s 1s/step - accuracy: 0.2806 - loss: 2.0588 - val_accuracy: 0.4044 - val_loss: 1.9219
# Epoch 23/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 33s 1s/step - accuracy: 0.3369 - loss: 2.0569 - val_accuracy: 0.3552 - val_loss: 1.9737
# Epoch 24/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 33s 1s/step - accuracy: 0.3214 - loss: 2.0149 - val_accuracy: 0.4208 - val_loss: 1.8623
# Epoch 25/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 34s 1s/step - accuracy: 0.3124 - loss: 2.0022 - val_accuracy: 0.3661 - val_loss: 1.8663
# Epoch 26/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 33s 1s/step - accuracy: 0.3246 - loss: 1.9907 - val_accuracy: 0.4262 - val_loss: 1.8554
# Epoch 27/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 33s 1s/step - accuracy: 0.3465 - loss: 1.9427 - val_accuracy: 0.4153 - val_loss: 1.7583
# Epoch 28/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 32s 1s/step - accuracy: 0.3506 - loss: 1.9099 - val_accuracy: 0.3880 - val_loss: 1.8935
# Epoch 29/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 33s 1s/step - accuracy: 0.3724 - loss: 1.8769 - val_accuracy: 0.4044 - val_loss: 1.8305
# Epoch 30/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 32s 1s/step - accuracy: 0.3682 - loss: 1.8513 - val_accuracy: 0.4372 - val_loss: 1.7074
# Epoch 31/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 32s 1s/step - accuracy: 0.3846 - loss: 1.8510 - val_accuracy: 0.4044 - val_loss: 1.7442
# Epoch 32/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 32s 1s/step - accuracy: 0.3804 - loss: 1.8287 - val_accuracy: 0.4153 - val_loss: 1.8275
# Epoch 33/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 32s 1s/step - accuracy: 0.3755 - loss: 1.8542 - val_accuracy: 0.4645 - val_loss: 1.6885
# Epoch 34/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 33s 1s/step - accuracy: 0.4063 - loss: 1.8246 - val_accuracy: 0.4372 - val_loss: 1.6597
# Epoch 35/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 33s 1s/step - accuracy: 0.3819 - loss: 1.8251 - val_accuracy: 0.4208 - val_loss: 1.7385
# Epoch 36/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 32s 1s/step - accuracy: 0.4221 - loss: 1.7628 - val_accuracy: 0.4699 - val_loss: 1.6173
# Epoch 37/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 33s 1s/step - accuracy: 0.3805 - loss: 1.7619 - val_accuracy: 0.4481 - val_loss: 1.6964
# Epoch 38/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 32s 1s/step - accuracy: 0.4263 - loss: 1.6794 - val_accuracy: 0.4536 - val_loss: 1.6014
# Epoch 39/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 32s 1s/step - accuracy: 0.4149 - loss: 1.7657 - val_accuracy: 0.4645 - val_loss: 1.5640
# Epoch 40/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 32s 1s/step - accuracy: 0.4322 - loss: 1.6672 - val_accuracy: 0.5246 - val_loss: 1.4662
# Epoch 41/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 33s 1s/step - accuracy: 0.4420 - loss: 1.6551 - val_accuracy: 0.4426 - val_loss: 1.6472
# Epoch 42/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 33s 1s/step - accuracy: 0.4253 - loss: 1.6731 - val_accuracy: 0.5137 - val_loss: 1.4633
# Epoch 43/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 33s 1s/step - accuracy: 0.4788 - loss: 1.5673 - val_accuracy: 0.5683 - val_loss: 1.4227
# Epoch 44/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 32s 1s/step - accuracy: 0.5112 - loss: 1.4384 - val_accuracy: 0.5628 - val_loss: 1.3425
# Epoch 45/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 33s 1s/step - accuracy: 0.5052 - loss: 1.4924 - val_accuracy: 0.5410 - val_loss: 1.3409
# Epoch 46/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 32s 1s/step - accuracy: 0.5012 - loss: 1.5310 - val_accuracy: 0.5847 - val_loss: 1.2656
# Epoch 47/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 32s 1s/step - accuracy: 0.5146 - loss: 1.3923 - val_accuracy: 0.5574 - val_loss: 1.3197
# Epoch 48/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 32s 1s/step - accuracy: 0.4998 - loss: 1.4148 - val_accuracy: 0.5738 - val_loss: 1.2156
# Epoch 49/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 32s 1s/step - accuracy: 0.5341 - loss: 1.3431 - val_accuracy: 0.5464 - val_loss: 1.3055
# Epoch 50/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 33s 1s/step - accuracy: 0.5308 - loss: 1.3349 - val_accuracy: 0.6011 - val_loss: 1.1442
# Epoch 51/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 33s 1s/step - accuracy: 0.5500 - loss: 1.3655 - val_accuracy: 0.6120 - val_loss: 1.1662
# Epoch 52/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 32s 1s/step - accuracy: 0.5584 - loss: 1.2888 - val_accuracy: 0.6175 - val_loss: 1.1397
# Epoch 53/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 32s 1s/step - accuracy: 0.5671 - loss: 1.2642 - val_accuracy: 0.6066 - val_loss: 1.0889
# Epoch 54/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 32s 1s/step - accuracy: 0.5809 - loss: 1.2554 - val_accuracy: 0.6339 - val_loss: 1.1500
# Epoch 55/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 32s 1s/step - accuracy: 0.5840 - loss: 1.1850 - val_accuracy: 0.6284 - val_loss: 1.1011
# Epoch 56/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 31s 1s/step - accuracy: 0.5938 - loss: 1.1606 - val_accuracy: 0.6448 - val_loss: 1.0663
# Epoch 57/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 32s 1s/step - accuracy: 0.5557 - loss: 1.2900 - val_accuracy: 0.6120 - val_loss: 1.1840
# Epoch 58/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 32s 1s/step - accuracy: 0.5937 - loss: 1.2225 - val_accuracy: 0.6503 - val_loss: 1.0198
# Epoch 59/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 32s 1s/step - accuracy: 0.6015 - loss: 1.1276 - val_accuracy: 0.6612 - val_loss: 1.0200
# Epoch 60/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 32s 1s/step - accuracy: 0.6273 - loss: 1.0876 - val_accuracy: 0.6175 - val_loss: 1.0623
# Epoch 61/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 31s 1s/step - accuracy: 0.5976 - loss: 1.1225 - val_accuracy: 0.6066 - val_loss: 1.0366
# Epoch 62/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 32s 1s/step - accuracy: 0.5824 - loss: 1.1652 - val_accuracy: 0.6503 - val_loss: 1.0144
# Epoch 63/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 32s 1s/step - accuracy: 0.5892 - loss: 1.1839 - val_accuracy: 0.6393 - val_loss: 1.0197
# Epoch 64/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 32s 1s/step - accuracy: 0.5981 - loss: 1.1447 - val_accuracy: 0.6175 - val_loss: 1.0084
# Epoch 65/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 33s 1s/step - accuracy: 0.6070 - loss: 1.1317 - val_accuracy: 0.6503 - val_loss: 0.9444
# Epoch 66/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 33s 1s/step - accuracy: 0.6015 - loss: 1.1109 - val_accuracy: 0.6776 - val_loss: 0.9438
# Epoch 67/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 33s 1s/step - accuracy: 0.6316 - loss: 1.0617 - val_accuracy: 0.6612 - val_loss: 0.9291
# Epoch 68/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 33s 1s/step - accuracy: 0.6273 - loss: 1.0206 - val_accuracy: 0.6885 - val_loss: 0.9152
# Epoch 69/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 33s 1s/step - accuracy: 0.6337 - loss: 1.0582 - val_accuracy: 0.6393 - val_loss: 1.0702
# Epoch 70/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 33s 1s/step - accuracy: 0.6232 - loss: 1.0387 - val_accuracy: 0.6776 - val_loss: 0.9796
# Epoch 71/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 32s 1s/step - accuracy: 0.6159 - loss: 1.1126 - val_accuracy: 0.6940 - val_loss: 0.8838
# Epoch 72/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 32s 1s/step - accuracy: 0.6458 - loss: 0.9821 - val_accuracy: 0.7104 - val_loss: 0.8437
# Epoch 73/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 33s 1s/step - accuracy: 0.6117 - loss: 1.0569 - val_accuracy: 0.6448 - val_loss: 0.9175
# Epoch 74/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 34s 1s/step - accuracy: 0.6629 - loss: 0.9607 - val_accuracy: 0.6995 - val_loss: 0.8546
# Epoch 75/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 33s 1s/step - accuracy: 0.6804 - loss: 0.9025 - val_accuracy: 0.6940 - val_loss: 0.8469
# Epoch 76/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 32s 1s/step - accuracy: 0.6849 - loss: 0.9290 - val_accuracy: 0.6667 - val_loss: 0.9994
# Epoch 77/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 33s 1s/step - accuracy: 0.6611 - loss: 0.9763 - val_accuracy: 0.6667 - val_loss: 0.9032
# Epoch 78/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 34s 1s/step - accuracy: 0.6787 - loss: 0.8985 - val_accuracy: 0.7049 - val_loss: 0.8606
# Epoch 79/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 33s 1s/step - accuracy: 0.6237 - loss: 0.9729 - val_accuracy: 0.6503 - val_loss: 0.9731
# Epoch 80/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 31s 1s/step - accuracy: 0.6535 - loss: 1.0227 - val_accuracy: 0.6776 - val_loss: 0.8609
# Epoch 81/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 33s 1s/step - accuracy: 0.6603 - loss: 0.9358 - val_accuracy: 0.6831 - val_loss: 0.8595
# Epoch 82/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 33s 1s/step - accuracy: 0.6601 - loss: 0.9401 - val_accuracy: 0.7104 - val_loss: 0.8944
# Epoch 83/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 33s 1s/step - accuracy: 0.6752 - loss: 0.9082 - val_accuracy: 0.6612 - val_loss: 0.9807
# Epoch 84/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 32s 1s/step - accuracy: 0.6341 - loss: 0.9984 - val_accuracy: 0.7158 - val_loss: 0.8076
# Epoch 85/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 32s 1s/step - accuracy: 0.6995 - loss: 0.8512 - val_accuracy: 0.7158 - val_loss: 0.7924
# Epoch 86/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 32s 1s/step - accuracy: 0.6928 - loss: 0.8659 - val_accuracy: 0.6995 - val_loss: 0.7872
# Epoch 87/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 33s 1s/step - accuracy: 0.6754 - loss: 0.8794 - val_accuracy: 0.7104 - val_loss: 0.8277
# Epoch 88/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 32s 1s/step - accuracy: 0.6922 - loss: 0.8723 - val_accuracy: 0.7541 - val_loss: 0.7700
# Epoch 89/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 33s 1s/step - accuracy: 0.6937 - loss: 0.8479 - val_accuracy: 0.7322 - val_loss: 0.7788
# Epoch 90/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 34s 1s/step - accuracy: 0.7211 - loss: 0.7818 - val_accuracy: 0.7377 - val_loss: 0.7674
# Epoch 91/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 33s 1s/step - accuracy: 0.7350 - loss: 0.7549 - val_accuracy: 0.7377 - val_loss: 0.7851
# Epoch 92/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 32s 1s/step - accuracy: 0.6890 - loss: 0.8539 - val_accuracy: 0.7377 - val_loss: 0.7487
# Epoch 93/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 34s 1s/step - accuracy: 0.7037 - loss: 0.8093 - val_accuracy: 0.7486 - val_loss: 0.7518
# Epoch 94/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 33s 1s/step - accuracy: 0.7173 - loss: 0.8126 - val_accuracy: 0.7049 - val_loss: 0.7638
# Epoch 95/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - accuracy: 0.6904 - loss: 0.8737 - val_accuracy: 0.6940 - val_loss: 0.8446
# Epoch 96/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 34s 1s/step - accuracy: 0.7180 - loss: 0.8073 - val_accuracy: 0.7268 - val_loss: 0.8024
# Epoch 97/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 34s 1s/step - accuracy: 0.7057 - loss: 0.8077 - val_accuracy: 0.7322 - val_loss: 0.7666
# Epoch 98/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - accuracy: 0.7121 - loss: 0.7865 - val_accuracy: 0.6995 - val_loss: 0.7586
# Epoch 99/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - accuracy: 0.7294 - loss: 0.8368 - val_accuracy: 0.7268 - val_loss: 0.7905
# Epoch 100/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 33s 1s/step - accuracy: 0.6814 - loss: 0.8500 - val_accuracy: 0.7322 - val_loss: 0.7598
# 3/3 - 2s - 777ms/step - accuracy: 0.7663 - loss: 0.7651
# Test accuracy: 0.7663043737411499

# %%
import numpy as np
import matplotlib.pyplot as plt

# Get one batch of images and labels from the test_generator
test_images, test_labels = next(test_generator)

# Make predictions on the test images
predictions = model.predict(test_images)

# Get the predicted class indices (the class with the highest probability for each image)
predicted_classes = np.argmax(predictions, axis=-1)

# Reverse class indices to labels
class_indices = test_generator.class_indices
class_labels = {v: k for k, v in class_indices.items()}

# Display images, predicted labels, and true labels
plt.figure(figsize=(12, 12))

for i in range(9):  # Display the first 9 images in the batch
    plt.subplot(3, 3, i+1)
    plt.imshow(test_images[i])  # Show the image
    plt.axis('off')
    
    # Get the predicted and actual label for each image
    predicted_label = class_labels[predicted_classes[i]]
    actual_label = class_labels[test_labels[i]]
    
    # Set the title with the predicted label and actual label
    plt.title(f"Pred: {predicted_label}, Actual: {actual_label}")

plt.tight_layout()
plt.show()
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
